# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np 
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import array as arr

# %%
df = pd.read_excel('allegations_202007271729.xlsx')
display(df)
# Out:
#        unique_mos_id first_name   last_name command_now  shield_no  \
# 0               4905     Johnny    Orellana     045 PCT          0
# 1               6101     Emilio    Melendez     050 PCT          0
# 2               6196     Thomas        Alps     052 PCT          0
# 3               6943    Anthony  Longobardi     062 PCT          0
# 4               6943    Anthony  Longobardi     062 PCT          0
# ...              ...        ...         ...         ...        ...
# 33353          36374     Ronald       Perez      YTH SD          0
# 33354          36374     Ronald       Perez      YTH SD          0
# 33355          36374     Ronald       Perez      YTH SD          0
# 33356          36374     Ronald       Perez      YTH SD          0
# 33357          36374     Ronald       Perez      YTH SD          0
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 0             26559               9           2012             2         2014
# ...

# %%
#stats desc en fonction de l'ethnie du plaignant
df = df[df['year_received']>= 2000]
dfB = df[df['complainant_ethnicity'] == 'Black']
dfW = df[df['complainant_ethnicity'] == 'White']
dfH = df[df['complainant_ethnicity'] == 'Hispanic']
dfO = df[df['complainant_ethnicity'] == 'Other Race']

# %%
print(dfB.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfB,'fado_type',title='Distribution of type of complaint for black complainants',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    10326
# Discourtesy            2284
# Force                  4040
# Offensive Language      392
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfW.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfW,'fado_type',title='Distribution of type of complaint for white complainants',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    1674
# Discourtesy            486
# Force                  552
# Offensive Language      66
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfH.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfH,'fado_type',title='Distribution of type of complaint for hispanic complainants',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    3667
# Discourtesy           1016
# Force                 1588
# Offensive Language     125
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfO.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfO,'fado_type',title='Distribution of type of complaint for other races complainants',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    389
# Discourtesy           123
# Force                 142
# Offensive Language     21
# Name: complaint_id, dtype: int64
# ...

# %%
#stats desc en fonction de l'ethnie du policier
df = df[df['year_received']>= 2000]
dfOB = df[df['mos_ethnicity'] == 'Black']
dfOW = df[df['mos_ethnicity'] == 'White']
dfOH = df[df['mos_ethnicity'] == 'Hispanic']
dfOA = df[df['mos_ethnicity'] == 'Asian']

# %%
print(dfOB.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfOB,'fado_type',title='Distribution of type of complaint for black officers',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    2949
# Discourtesy            615
# Force                 1050
# Offensive Language     101
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfOW.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfOW,'fado_type',title='Distribution of type of complaint for white officers',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    10546
# Discourtesy            2358
# Force                  3557
# Offensive Language      375
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfOH.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfOH,'fado_type',title='Distribution of type of complaint for hispanic officers',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    5525
# Discourtesy           1211
# Force                 2037
# Offensive Language     167
# Name: complaint_id, dtype: int64
# ...

# %%
print(dfOA.groupby('fado_type').count()['complaint_id'])
fig = px.pie(dfOA,'fado_type',title='Distribution of type of complaint for asian officers',width=700, height=300)
fig=fig.update_traces(textinfo="percent+label")
fig.show()
# Out:
# fado_type
# Abuse of Authority    759
# Discourtesy           144
# Force                 243
# Offensive Language     17
# Name: complaint_id, dtype: int64
# ...
